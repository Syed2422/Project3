# %%
# %pip install transformers datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import pipeline

# %%
finbert = BertForSequenceClassification.from_pretrained('ProsusAI/finbert', num_labels=3)
tokenizer = BertTokenizer.from_pretrained('ProsusAI/finbert')

# %%
nlp_pipeline = pipeline("sentiment-analysis", model=finbert, tokenizer=tokenizer)

# %%
with open('c:/Users/jieja/OneDrive/AI class Resources files/Project 3/Project3-main/Project3-main/transcript.txt', 'r') as file:
    content = file.read()

print(content)
# Out:
# Suhasini Chandramouli -- Director, Investor Relations
#
# Good afternoon, and welcome to the Apple Q4 fiscal year 2024 earnings conference call. My name is Suhasini Chandramouli, director of investor relations. Today's call is being recorded. Speaking first today are Apple's CEO, Tim Cook; and CFO, Luca Maestri; and they'll be joined by Kevan Parekh, vice president of financial planning and analysis.
#
# ...

# %%
# Split the content into smaller chunks
max_length = 512
chunks = [content[i:i+max_length] for i in range(0, len(content), max_length)]

# Process each chunk
results = []
for chunk in chunks:
	result = nlp_pipeline(chunk)
	results.extend(result)

print(results)
# Out:
# [{'label': 'neutral', 'score': 0.9306329488754272}, {'label': 'neutral', 'score': 0.8971436619758606}, {'label': 'neutral', 'score': 0.9512040019035339}, {'label': 'positive', 'score': 0.9432870149612427}, {'label': 'positive', 'score': 0.8356069326400757}, {'label': 'neutral', 'score': 0.6645438075065613}, {'label': 'neutral', 'score': 0.6512099504470825}, {'label': 'positive', 'score': 0.7613707184791565}, {'label': 'positive', 'score': 0.7672784924507141}, {'label': 'positive', 'score': 0.8662930130958557}, {'label': 'neutral', 'score': 0.714974045753479}, {'label': 'negative', 'score': 0.9571675658226013}, {'label': 'positive', 'score': 0.5663641691207886}, {'label': 'positive', 'score': 0.7146897315979004}, {'label': 'neutral', 'score': 0.7145129442214966}, {'label': 'positive', 'score': 0.8948218822479248}, {'label': 'neutral', 'score': 0.8742208480834961}, {'label': 'neutral', 'score': 0.6873579025268555}, {'label': 'neutral', 'score': 0.5464637875556946}, {'label': 'positive'
# ...

# %%
from collections import defaultdict
results = [{'label': 'neutral', 'score': 0.9306329488754272}, {'label': 'neutral', 'score': 0.8971436619758606}, {'label': 'neutral', 'score': 0.9512040019035339}, {'label': 'positive', 'score': 0.9432870149612427}, {'label': 'positive', 'score': 0.8356069326400757}, {'label': 'neutral', 'score': 0.6645438075065613}, {'label': 'neutral', 'score': 0.6512099504470825}, {'label': 'positive', 'score': 0.7613707184791565}, {'label': 'positive', 'score': 0.7672784924507141}, {'label': 'positive', 'score': 0.8662930130958557}, {'label': 'neutral', 'score': 0.714974045753479}, {'label': 'negative', 'score': 0.9571675658226013}, {'label': 'positive', 'score': 0.5663641691207886}, {'label': 'positive', 'score': 0.7146897315979004}, {'label': 'neutral', 'score': 0.7145129442214966}, {'label': 'positive', 'score': 0.8948218822479248}, {'label': 'neutral', 'score': 0.8742208480834961}, {'label': 'neutral', 'score': 0.6873579025268555}, {'label': 'neutral', 'score': 0.5464637875556946}, {'label': 'positive', 'score': 0.8322330713272095}, {'label': 'positive', 'score': 0.7366112470626831}, {'label': 'neutral', 'score': 0.7530785799026489}, {'label': 'neutral', 'score': 0.6046877503395081}, {'label': 'positive', 'score': 0.7953651547431946}, {'label': 'positive', 'score': 0.9535664319992065}, {'label': 'positive', 'score': 0.9540317058563232}, {'label': 'positive', 'score': 0.9043877720832825}, {'label': 'positive', 'score': 0.9271998405456543}, {'label': 'positive', 'score': 0.9420430660247803}, {'label': 'positive', 'score': 0.914271891117096}, {'label': 'negative', 'score': 0.955224335193634}, {'label': 'positive', 'score': 0.9489218592643738}, {'label': 'positive', 'score': 0.8098839521408081}, {'label': 'positive', 'score': 0.8497574329376221}, {'label': 'positive', 'score': 0.8299985527992249}, {'label': 'neutral', 'score': 0.8494606018066406}, {'label': 'positive', 'score': 0.6344105005264282}, {'label': 'neutral', 'score': 0.8828336596488953}, {'label': 'neutral', 'score': 0.9121093153953552}, {'label': 'neutral', 'score': 0.7519626617431641}, {'label': 'neutral', 'score': 0.7361239194869995}, {'label': 'positive', 'score': 0.8139358162879944}, {'label': 'positive', 'score': 0.7252123355865479}, {'label': 'neutral', 'score': 0.9230602383613586}, {'label': 'neutral', 'score': 0.7470835447311401}, {'label': 'neutral', 'score': 0.8428388237953186}, {'label': 'neutral', 'score': 0.8187693357467651}, {'label': 'positive', 'score': 0.5507302284240723}, {'label': 'neutral', 'score': 0.7988056540489197}, {'label': 'positive', 'score': 0.7381830811500549}, {'label': 'positive', 'score': 0.49718931317329407}, {'label': 'negative', 'score': 0.7694904208183289}, {'label': 'positive', 'score': 0.8987650871276855}, {'label': 'neutral', 'score': 0.8796678185462952}, {'label': 'neutral', 'score': 0.7233354449272156}, {'label': 'neutral', 'score': 0.5897291898727417}, {'label': 'neutral', 'score': 0.8692969679832458}, {'label': 'neutral', 'score': 0.9142841100692749}, {'label': 'neutral', 'score': 0.6836631298065186}, {'label': 'neutral', 'score': 0.872948408126831}, {'label': 'positive', 'score': 0.6823501586914062}, {'label': 'positive', 'score': 0.7221707701683044}, {'label': 'positive', 'score': 0.6890758872032166}, {'label': 'positive', 'score': 0.5769211649894714}, {'label': 'positive', 'score': 0.8377662301063538}, {'label': 'neutral', 'score': 0.6712608337402344}, {'label': 'positive', 'score': 0.7797543406486511}, {'label': 'positive', 'score': 0.777606725692749}, {'label': 'negative', 'score': 0.9545937180519104}, {'label': 'neutral', 'score': 0.8783125877380371}, {'label': 'neutral', 'score': 0.9275739789009094}, {'label': 'neutral', 'score': 0.8739164471626282}, {'label': 'neutral', 'score': 0.7323465347290039}, {'label': 'neutral', 'score': 0.8565970063209534}, {'label': 'neutral', 'score': 0.9248495101928711}, {'label': 'neutral', 'score': 0.8405551314353943}, {'label': 'neutral', 'score': 0.9117556810379028}, {'label': 'neutral', 'score': 0.8221606016159058}, {'label': 'positive', 'score': 0.6902843713760376}, {'label': 'neutral', 'score': 0.7294023036956787}, {'label': 'neutral', 'score': 0.9362720251083374}, {'label': 'neutral', 'score': 0.7797011137008667}, {'label': 'neutral', 'score': 0.6982157230377197}, {'label': 'neutral', 'score': 0.8561120629310608}, {'label': 'neutral', 'score': 0.9164429306983948}, {'label': 'neutral', 'score': 0.9215277433395386}, {'label': 'neutral', 'score': 0.9302834868431091}, {'label': 'neutral', 'score': 0.8877930045127869}, {'label': 'neutral', 'score': 0.900165319442749}, {'label': 'neutral', 'score': 0.5324068665504456}, {'label': 'positive', 'score': 0.9535624384880066}, {'label': 'neutral', 'score': 0.6394244432449341}, {'label': 'neutral', 'score': 0.5190016627311707}, {'label': 'neutral', 'score': 0.7996686697006226}, {'label': 'neutral', 'score': 0.9250574707984924}]

# %%
categories = defaultdict(list)
for entry in results:
    categories[entry['label']].append(entry['score'])
summary = {label:(len(scores), sum(scores)/len(scores)) for label, scores in categories.items()}
dominant_sentiment = max(summary.items(), key=lambda x: (x[1][0], x[1][1]))[0]
print(f"Dominant Sentiment: {dominant_sentiment}")
print(f"Summary: {summary}")
# Out:
# Dominant Sentiment: neutral
# Summary: {'neutral': (54, 0.7999408554147791), 'positive': (37, 0.7923216860036593), 'negative': (4, 0.9091190099716187)}

# %%
import tensorflow as tf### models
import numpy as np### math computations
import matplotlib.pyplot as plt### plotting bar chart
import sklearn### machine learning library
# import cv2## image processing
from sklearn.metrics import confusion_matrix, roc_curve### metrics
#import seaborn as sns### visualizations
import datetime # For Datetime Functions
import pathlib # handling files and paths on your operating system
import io # dealing with various types of I/O
import os 
import re # for Regular Expressions
import string
import time
from numpy import random
import gensim.downloader as api # to download pre-trained model datasets and word embeddings from Gensim's repository
from PIL import Image # manipulating images, resizing, cropping, adding text
import tensorflow_datasets as tfds # Tf Datasets
import tensorflow_probability as tfp
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import (Dense,Flatten,InputLayer,BatchNormalization,
                                     Dropout,Input,LayerNormalization)
from tensorflow.keras.losses import (BinaryCrossentropy,CategoricalCrossentropy,
                                    SparseCategoricalCrossentropy)
from tensorflow.keras.metrics import (Accuracy,TopKCategoricalAccuracy,
                                 CategoricalAccuracy, SparseCategoricalAccuracy)
from tensorflow.keras.optimizers import Adam
from google.colab import drive
from google.colab import files
from datasets import load_dataset
from transformers import (BertTokenizerFast,TFBertTokenizer,BertTokenizer,RobertaTokenizerFast,
                          DataCollatorWithPadding,TFRobertaForSequenceClassification,TFBertForSequenceClassification,
                          TFBertModel,create_optimizer)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 # import cv2## image processing
#       6 from sklearn.metrics import confusion_matrix, roc_curve### metrics
# ----> 7 import seaborn as sns### visualizations
#       8 import datetime # For Datetime Functions
#       9 import pathlib # handling files and paths on your operating system
#
# ModuleNotFoundError: No module named 'seaborn'
